# %%
# 동빈나 튜토리얼
# https://github.com/ndb796/Deep-Learning-Paper-Review-and-Practice/blob/master/code_practices/GAN_for_MNIST_Tutorial.ipynb
# <Generative Adversarial Networks> (NIPS 2014)

# %%
import torch
import torch.nn as nn

from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.utils import save_image

# %%
latent_dim = 100


# 생성자(Generator) 클래스 정의
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        # 하나의 블록(block) 정의
        def block(input_dim, output_dim, normalize=True):
            layers = [nn.Linear(input_dim, output_dim)]
            if normalize:
                # 배치 정규화(batch normalization) 수행(차원 동일)
                layers.append(nn.BatchNorm1d(output_dim, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        # 생성자 모델은 연속적인 여러 개의 블록을 가짐
        self.model = nn.Sequential(
            *block(latent_dim, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, 1 * 28 * 28),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        img = img.view(img.size(0), 1, 28, 28)
        return img

# %%
# 판별자(Discriminator) 클래스 정의
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(1 * 28 * 28, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )

    # 이미지에 대한 판별 결과를 반환
    def forward(self, img):
        flattened = img.view(img.size(0), -1)
        output = self.model(flattened)

        return output

# %%
transforms_train = transforms.Compose([
    transforms.Resize(28),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

train_dataset = datasets.MNIST(root="./dataset", train=True, download=True, transform=transforms_train)
dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./dataset/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=9912422.0), HTML(value='')))
# Extracting ./dataset/MNIST/raw/train-images-idx3-ubyte.gz to ./dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./dataset/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=28881.0), HTML(value='')))
# Extracting ./dataset/MNIST/raw/train-labels-idx1-ubyte.gz to ./dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=1648877.0), HTML(value='')))
# Extracting ./dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to ./dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=4542.0), HTML(value='')))
# Extracting ./dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./dataset/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
# 생성자(generator)와 판별자(discriminator) 초기화
generator = Generator()
discriminator = Discriminator()

generator.cuda()
discriminator.cuda()

# 손실 함수(loss function)
adversarial_loss = nn.BCELoss()
adversarial_loss.cuda()

# 학습률(learning rate) 설정
lr = 0.0002

# 생성자와 판별자를 위한 최적화 함수
optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))

# %%
import time

n_epochs = 200 # 학습의 횟수(epoch) 설정
sample_interval = 2000 # 몇 번의 배치(batch)마다 결과를 출력할 것인지 설정
start_time = time.time()

for epoch in range(n_epochs):
    for i, (imgs, _) in enumerate(dataloader):

        # 진짜(real) 이미지와 가짜(fake) 이미지에 대한 정답 레이블 생성
        real = torch.cuda.FloatTensor(imgs.size(0), 1).fill_(1.0) # 진짜(real): 1
        fake = torch.cuda.FloatTensor(imgs.size(0), 1).fill_(0.0) # 가짜(fake): 0

        real_imgs = imgs.cuda()

        """ 생성자(generator)를 학습합니다. """
        optimizer_G.zero_grad()

        # 랜덤 노이즈(noise) 샘플링
        z = torch.normal(mean=0, std=1, size=(imgs.shape[0], latent_dim)).cuda()

        # 이미지 생성
        generated_imgs = generator(z)

        # 생성자(generator)의 손실(loss) 값 계산
        g_loss = adversarial_loss(discriminator(generated_imgs), real)

        # 생성자(generator) 업데이트
        g_loss.backward()
        optimizer_G.step()

        """ 판별자(discriminator)를 학습합니다. """
        optimizer_D.zero_grad()

        # 판별자(discriminator)의 손실(loss) 값 계산
        real_loss = adversarial_loss(discriminator(real_imgs), real)
        fake_loss = adversarial_loss(discriminator(generated_imgs.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2

        # 판별자(discriminator) 업데이트
        d_loss.backward()
        optimizer_D.step()

        done = epoch * len(dataloader) + i
        if done % sample_interval == 0:
            # 생성된 이미지 중에서 25개만 선택하여 5 X 5 격자 이미지에 출력
            save_image(generated_imgs.data[:25], f"{done}.png", nrow=5, normalize=True)

    # 하나의 epoch이 끝날 때마다 로그(log) 출력
    print(f"[Epoch {epoch}/{n_epochs}] [D loss: {d_loss.item():.6f}] [G loss: {g_loss.item():.6f}] [Elapsed time: {time.time() - start_time:.2f}s]")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [Epoch 0/200] [D loss: 0.434297] [G loss: 1.381385] [Elapsed time: 10.70s]
# [Epoch 1/200] [D loss: 0.416288] [G loss: 2.208766] [Elapsed time: 22.11s]
# [Epoch 2/200] [D loss: 0.323714] [G loss: 1.870928] [Elapsed time: 33.72s]
# [Epoch 3/200] [D loss: 0.219463] [G loss: 1.587536] [Elapsed time: 44.46s]
# [Epoch 4/200] [D loss: 0.207004] [G loss: 2.449730] [Elapsed time: 55.35s]
# [Epoch 5/200] [D loss: 0.304818] [G loss: 1.770486] [Elapsed time: 65.76s]
# [Epoch 6/200] [D loss: 0.469944] [G loss: 4.207968] [Elapsed time: 76.10s]
# [Epoch 7/200] [D loss: 0.698684] [G loss: 0.317758] [Elapsed time: 87.75s]
# [Epoch 8/200] [D loss: 0.137619] [G loss: 2.124595] [Elapsed time: 99.11s]
# [Epoch 9/200] [D loss: 0.261468] [G loss: 1.584657] [Elapsed time: 109.60s]
# [Epoch 10/200] [D loss: 0.195332] [G loss: 1.715546] [Elapsed time: 119.93s]
# [Epoch 11/200] [D loss: 0.537217] [G loss: 4.196442] [Elapsed time: 130.32s]
# [Epoch 12/200] [D loss: 0.274214] [G loss: 1.374384] [Elapsed time: 140.63s]
# [Epoch 13/200] [D loss: 0.221944] [G loss: 2.148658] [Elapsed time: 151.91s]
# [Epoch 14/200] [D loss: 0.140022] [G loss: 1.753184] [Elapsed time: 163.35s]
# [Epoch 15/200] [D loss: 0.202349] [G loss: 2.126249] [Elapsed time: 174.12s]
# [Epoch 16/200] [D loss: 0.201790] [G loss: 1.535994] [Elapsed time: 184.54s]
# [Epoch 17/200] [D loss: 0.167625] [G loss: 2.647989] [Elapsed time: 195.03s]
# [Epoch 18/200] [D loss: 0.146565] [G loss: 2.121905] [Elapsed time: 205.39s]
# [Epoch 19/200] [D loss: 0.132379] [G loss: 2.588522] [Elapsed time: 216.43s]
# [Epoch 20/200] [D loss: 0.155943] [G loss: 3.381739] [Elapsed time: 227.77s]
# [Epoch 21/200] [D loss: 0.204421] [G loss: 1.478552] [Elapsed time: 238.66s]
# [Epoch 22/200] [D loss: 0.284715] [G loss: 2.012824] [Elapsed time: 249.10s]
# [Epoch 23/200] [D loss: 0.397864] [G loss: 0.730667] [Elapsed time: 259.44s]
# [Epoch 24/200] [D loss: 0.154643] [G loss: 1.766311] [Elapsed time: 269.72s]
# [Epoch 25/200] [D loss: 0.196849] [G loss: 2.609227] [Elapsed time: 280.61s]
# [Epoch 26/200] [D loss: 0.112163] [G loss: 4.054107] [Elapsed time: 291.93s]
# [Epoch 27/200] [D loss: 0.247375] [G loss: 1.563389] [Elapsed time: 302.91s]
# [Epoch 28/200] [D loss: 0.229878] [G loss: 1.556999] [Elapsed time: 313.24s]
# [Epoch 29/200] [D loss: 0.221971] [G loss: 2.135682] [Elapsed time: 323.66s]
# [Epoch 30/200] [D loss: 0.207292] [G loss: 1.599967] [Elapsed time: 334.04s]
# [Epoch 31/200] [D loss: 0.171422] [G loss: 3.273880] [Elapsed time: 345.02s]
# [Epoch 32/200] [D loss: 0.198735] [G loss: 1.827719] [Elapsed time: 356.40s]
# [Epoch 33/200] [D loss: 0.073175] [G loss: 2.339705] [Elapsed time: 367.82s]
# [Epoch 34/200] [D loss: 0.097733] [G loss: 2.800225] [Elapsed time: 378.92s]
# [Epoch 35/200] [D loss: 0.189005] [G loss: 2.210427] [Elapsed time: 390.59s]
# [Epoch 36/200] [D loss: 0.528456] [G loss: 6.856236] [Elapsed time: 401.92s]
# [Epoch 37/200] [D loss: 0.153219] [G loss: 2.071150] [Elapsed time: 412.59s]
# [Epoch 38/200] [D loss: 0.086398] [G loss: 3.602275] [Elapsed time: 423.37s]
# [Epoch 39/200] [D loss: 0.137020] [G loss: 2.660571] [Elapsed time: 433.93s]
# [Epoch 40/200] [D loss: 0.099466] [G loss: 2.897057] [Elapsed time: 445.18s]
# [Epoch 41/200] [D loss: 0.169637] [G loss: 1.845678] [Elapsed time: 456.93s]
# [Epoch 42/200] [D loss: 0.306914] [G loss: 1.401221] [Elapsed time: 468.35s]
# [Epoch 43/200] [D loss: 0.348843] [G loss: 6.306213] [Elapsed time: 479.27s]
# [Epoch 44/200] [D loss: 0.456246] [G loss: 0.789553] [Elapsed time: 489.90s]
# [Epoch 45/200] [D loss: 0.502918] [G loss: 6.820322] [Elapsed time: 500.67s]
# [Epoch 46/200] [D loss: 0.092468] [G loss: 3.279641] [Elapsed time: 512.02s]
# [Epoch 47/200] [D loss: 0.080411] [G loss: 2.843325] [Elapsed time: 523.77s]
# [Epoch 48/200] [D loss: 0.234256] [G loss: 1.924333] [Elapsed time: 535.25s]
# [Epoch 49/200] [D loss: 0.288132] [G loss: 1.511492] [Elapsed time: 546.25s]
# [Epoch 50/200] [D loss: 0.213607] [G loss: 1.855436] [Elapsed time: 557.21s]
# [Epoch 51/200] [D loss: 0.322936] [G loss: 2.819233] [Elapsed time: 568.07s]
# [Epoch 52/200] [D loss: 0.297950] [G loss: 1.726276] [Elapsed time: 579.37s]
# [Epoch 53/200] [D loss: 0.215001] [G loss: 2.424513] [Elapsed time: 591.07s]
# [Epoch 54/200] [D loss: 0.189116] [G loss: 4.142360] [Elapsed time: 602.25s]
# [Epoch 55/200] [D loss: 0.131548] [G loss: 2.802373] [Elapsed time: 612.90s]
# [Epoch 56/200] [D loss: 0.185052] [G loss: 2.231965] [Elapsed time: 623.52s]
# [Epoch 57/200] [D loss: 0.134247] [G loss: 2.818790] [Elapsed time: 633.97s]
# [Epoch 58/200] [D loss: 0.449856] [G loss: 1.138674] [Elapsed time: 645.34s]
# [Epoch 59/200] [D loss: 0.959427] [G loss: 8.346413] [Elapsed time: 657.00s]
# [Epoch 60/200] [D loss: 0.260904] [G loss: 1.621892] [Elapsed time: 668.62s]
# [Epoch 61/200] [D loss: 0.156046] [G loss: 1.934969] [Elapsed time: 680.11s]
# [Epoch 62/200] [D loss: 0.193594] [G loss: 1.710931] [Elapsed time: 692.26s]
# [Epoch 63/200] [D loss: 0.188411] [G loss: 2.823725] [Elapsed time: 703.64s]
# [Epoch 64/200] [D loss: 0.173974] [G loss: 1.795449] [Elapsed time: 715.01s]
# [Epoch 65/200] [D loss: 0.188949] [G loss: 2.379393] [Elapsed time: 726.31s]
# [Epoch 66/200] [D loss: 0.269672] [G loss: 1.899534] [Elapsed time: 737.45s]
# [Epoch 67/200] [D loss: 0.334930] [G loss: 1.618103] [Elapsed time: 749.16s]
# [Epoch 68/200] [D loss: 0.215792] [G loss: 3.019830] [Elapsed time: 760.74s]
# [Epoch 69/200] [D loss: 0.158007] [G loss: 2.737006] [Elapsed time: 771.48s]
# [Epoch 70/200] [D loss: 0.161259] [G loss: 2.536080] [Elapsed time: 782.10s]
# [Epoch 71/200] [D loss: 0.173318] [G loss: 3.370279] [Elapsed time: 792.68s]
# [Epoch 72/200] [D loss: 0.211716] [G loss: 2.586076] [Elapsed time: 803.42s]
# [Epoch 73/200] [D loss: 0.174574] [G loss: 1.861960] [Elapsed time: 815.05s]
# [Epoch 74/200] [D loss: 0.281838] [G loss: 1.527225] [Elapsed time: 826.65s]
# [Epoch 75/200] [D loss: 0.171865] [G loss: 1.996653] [Elapsed time: 837.49s]
# [Epoch 76/200] [D loss: 0.245293] [G loss: 3.072255] [Elapsed time: 848.16s]
# [Epoch 77/200] [D loss: 0.186578] [G loss: 2.303153] [Elapsed time: 858.88s]
# [Epoch 78/200] [D loss: 0.311883] [G loss: 1.816121] [Elapsed time: 869.53s]
# [Epoch 79/200] [D loss: 0.277482] [G loss: 2.610739] [Elapsed time: 881.11s]
# [Epoch 80/200] [D loss: 0.189172] [G loss: 3.909828] [Elapsed time: 892.67s]
# [Epoch 81/200] [D loss: 0.241639] [G loss: 2.125120] [Elapsed time: 903.18s]
# [Epoch 82/200] [D loss: 0.184577] [G loss: 2.067883] [Elapsed time: 913.94s]
# [Epoch 83/200] [D loss: 0.396692] [G loss: 1.254297] [Elapsed time: 924.74s]
# [Epoch 84/200] [D loss: 0.247935] [G loss: 2.611278] [Elapsed time: 935.42s]
# [Epoch 85/200] [D loss: 0.236542] [G loss: 2.156108] [Elapsed time: 946.82s]
# [Epoch 86/200] [D loss: 0.244572] [G loss: 1.788161] [Elapsed time: 958.26s]
# [Epoch 87/200] [D loss: 0.228845] [G loss: 1.666752] [Elapsed time: 969.22s]
# [Epoch 88/200] [D loss: 0.209116] [G loss: 2.420254] [Elapsed time: 980.88s]
# [Epoch 89/200] [D loss: 0.140930] [G loss: 2.364710] [Elapsed time: 992.45s]
# [Epoch 90/200] [D loss: 0.186727] [G loss: 2.061112] [Elapsed time: 1003.48s]
# [Epoch 91/200] [D loss: 0.393496] [G loss: 1.176809] [Elapsed time: 1014.74s]
# [Epoch 92/200] [D loss: 0.103194] [G loss: 4.421044] [Elapsed time: 1025.95s]
# [Epoch 93/200] [D loss: 0.272637] [G loss: 4.342531] [Elapsed time: 1037.59s]
# [Epoch 94/200] [D loss: 0.130357] [G loss: 2.591835] [Elapsed time: 1049.47s]
# [Epoch 95/200] [D loss: 0.185200] [G loss: 2.914747] [Elapsed time: 1060.83s]
# [Epoch 96/200] [D loss: 0.252586] [G loss: 3.502021] [Elapsed time: 1071.77s]
# [Epoch 97/200] [D loss: 0.259401] [G loss: 1.850457] [Elapsed time: 1082.65s]
# [Epoch 98/200] [D loss: 0.174566] [G loss: 2.645070] [Elapsed time: 1093.69s]
# [Epoch 99/200] [D loss: 0.186100] [G loss: 3.070737] [Elapsed time: 1105.05s]
# [Epoch 100/200] [D loss: 0.128281] [G loss: 2.637396] [Elapsed time: 1116.81s]
# [Epoch 101/200] [D loss: 0.229748] [G loss: 2.972604] [Elapsed time: 1128.32s]
# [Epoch 102/200] [D loss: 0.203603] [G loss: 3.192501] [Elapsed time: 1139.10s]
# [Epoch 103/200] [D loss: 0.208806] [G loss: 3.066407] [Elapsed time: 1149.99s]
# [Epoch 104/200] [D loss: 0.286839] [G loss: 2.614753] [Elapsed time: 1160.86s]
# [Epoch 105/200] [D loss: 0.206602] [G loss: 2.070228] [Elapsed time: 1172.32s]
# [Epoch 106/200] [D loss: 0.248902] [G loss: 3.718403] [Elapsed time: 1184.05s]
# [Epoch 107/200] [D loss: 0.226933] [G loss: 2.878689] [Elapsed time: 1195.38s]
# [Epoch 108/200] [D loss: 0.152602] [G loss: 2.843388] [Elapsed time: 1206.39s]
# [Epoch 109/200] [D loss: 0.255742] [G loss: 1.778799] [Elapsed time: 1217.35s]
# [Epoch 110/200] [D loss: 0.281536] [G loss: 3.740821] [Elapsed time: 1228.22s]
# [Epoch 111/200] [D loss: 0.240551] [G loss: 2.447142] [Elapsed time: 1239.71s]
# [Epoch 112/200] [D loss: 0.159060] [G loss: 3.195135] [Elapsed time: 1251.49s]
# [Epoch 113/200] [D loss: 0.169183] [G loss: 2.315274] [Elapsed time: 1262.70s]
# [Epoch 114/200] [D loss: 0.181190] [G loss: 2.678397] [Elapsed time: 1273.64s]
# [Epoch 115/200] [D loss: 0.220720] [G loss: 2.456567] [Elapsed time: 1284.51s]
# [Epoch 116/200] [D loss: 0.230347] [G loss: 2.651562] [Elapsed time: 1295.20s]
# [Epoch 117/200] [D loss: 0.193545] [G loss: 2.709175] [Elapsed time: 1306.76s]
# [Epoch 118/200] [D loss: 0.145141] [G loss: 2.381291] [Elapsed time: 1318.59s]
# [Epoch 119/200] [D loss: 0.193289] [G loss: 2.850488] [Elapsed time: 1330.04s]
# [Epoch 120/200] [D loss: 0.398055] [G loss: 4.421056] [Elapsed time: 1341.89s]
# [Epoch 121/200] [D loss: 0.185428] [G loss: 2.043939] [Elapsed time: 1353.68s]
# [Epoch 122/200] [D loss: 0.238658] [G loss: 2.446942] [Elapsed time: 1364.79s]
# [Epoch 123/200] [D loss: 0.396519] [G loss: 2.272488] [Elapsed time: 1375.71s]
# [Epoch 124/200] [D loss: 0.188165] [G loss: 2.437664] [Elapsed time: 1386.29s]
# [Epoch 125/200] [D loss: 0.232067] [G loss: 2.492006] [Elapsed time: 1396.76s]
# [Epoch 126/200] [D loss: 0.307336] [G loss: 1.939634] [Elapsed time: 1408.25s]
# [Epoch 127/200] [D loss: 0.245941] [G loss: 2.312941] [Elapsed time: 1419.82s]
# [Epoch 128/200] [D loss: 0.448502] [G loss: 4.010419] [Elapsed time: 1430.61s]
# [Epoch 129/200] [D loss: 0.257374] [G loss: 2.586815] [Elapsed time: 1441.25s]
# [Epoch 130/200] [D loss: 0.250064] [G loss: 2.395793] [Elapsed time: 1451.88s]
# [Epoch 131/200] [D loss: 0.236932] [G loss: 2.229341] [Elapsed time: 1462.46s]
# [Epoch 132/200] [D loss: 0.251102] [G loss: 2.344074] [Elapsed time: 1473.99s]
# [Epoch 133/200] [D loss: 0.338492] [G loss: 1.681533] [Elapsed time: 1485.49s]
# [Epoch 134/200] [D loss: 0.298358] [G loss: 1.574046] [Elapsed time: 1496.26s]
# [Epoch 135/200] [D loss: 0.369094] [G loss: 1.837243] [Elapsed time: 1506.92s]
# [Epoch 136/200] [D loss: 0.215767] [G loss: 2.290545] [Elapsed time: 1517.58s]
# [Epoch 137/200] [D loss: 0.332258] [G loss: 2.023451] [Elapsed time: 1528.22s]
# [Epoch 138/200] [D loss: 0.212173] [G loss: 2.985528] [Elapsed time: 1539.93s]
# [Epoch 139/200] [D loss: 0.407138] [G loss: 1.133023] [Elapsed time: 1551.60s]
# [Epoch 140/200] [D loss: 0.276927] [G loss: 3.038207] [Elapsed time: 1562.43s]
# [Epoch 141/200] [D loss: 0.255823] [G loss: 1.691210] [Elapsed time: 1573.04s]
# [Epoch 142/200] [D loss: 0.235995] [G loss: 2.182828] [Elapsed time: 1583.71s]
# [Epoch 143/200] [D loss: 0.245891] [G loss: 1.815056] [Elapsed time: 1594.34s]
# [Epoch 144/200] [D loss: 0.311971] [G loss: 3.372505] [Elapsed time: 1605.76s]
# [Epoch 145/200] [D loss: 0.274606] [G loss: 2.158868] [Elapsed time: 1617.30s]
# [Epoch 146/200] [D loss: 0.321210] [G loss: 1.991285] [Elapsed time: 1628.04s]
# [Epoch 147/200] [D loss: 0.216892] [G loss: 1.707391] [Elapsed time: 1639.65s]
# [Epoch 148/200] [D loss: 0.332351] [G loss: 1.465811] [Elapsed time: 1651.22s]
# [Epoch 149/200] [D loss: 0.331248] [G loss: 1.221266] [Elapsed time: 1661.94s]
# [Epoch 150/200] [D loss: 0.261267] [G loss: 1.837248] [Elapsed time: 1672.58s]
# [Epoch 151/200] [D loss: 0.289316] [G loss: 1.558222] [Elapsed time: 1683.25s]
# [Epoch 152/200] [D loss: 0.299517] [G loss: 1.869443] [Elapsed time: 1693.76s]
# [Epoch 153/200] [D loss: 0.558059] [G loss: 4.743054] [Elapsed time: 1705.22s]
# [Epoch 154/200] [D loss: 0.225297] [G loss: 1.836959] [Elapsed time: 1716.68s]
# [Epoch 155/200] [D loss: 0.327332] [G loss: 1.874909] [Elapsed time: 1727.45s]
# [Epoch 156/200] [D loss: 0.247742] [G loss: 2.299530] [Elapsed time: 1738.12s]
# [Epoch 157/200] [D loss: 0.318122] [G loss: 1.532299] [Elapsed time: 1748.64s]
# [Epoch 158/200] [D loss: 0.207671] [G loss: 2.061587] [Elapsed time: 1759.18s]
# [Epoch 159/200] [D loss: 0.217208] [G loss: 2.365062] [Elapsed time: 1770.70s]
# [Epoch 160/200] [D loss: 0.215717] [G loss: 2.291291] [Elapsed time: 1782.23s]
# [Epoch 161/200] [D loss: 0.283483] [G loss: 2.408475] [Elapsed time: 1792.85s]
# [Epoch 162/200] [D loss: 0.323434] [G loss: 1.966211] [Elapsed time: 1803.32s]
# [Epoch 163/200] [D loss: 0.342482] [G loss: 2.294034] [Elapsed time: 1813.75s]
# [Epoch 164/200] [D loss: 0.307826] [G loss: 2.095146] [Elapsed time: 1824.30s]
# [Epoch 165/200] [D loss: 0.343127] [G loss: 1.400952] [Elapsed time: 1835.60s]
# [Epoch 166/200] [D loss: 0.269850] [G loss: 2.334836] [Elapsed time: 1846.99s]
# [Epoch 167/200] [D loss: 0.288150] [G loss: 3.051195] [Elapsed time: 1857.77s]
# [Epoch 168/200] [D loss: 0.295515] [G loss: 1.870294] [Elapsed time: 1868.26s]
# [Epoch 169/200] [D loss: 0.257268] [G loss: 1.754266] [Elapsed time: 1878.74s]
# [Epoch 170/200] [D loss: 0.225388] [G loss: 2.593420] [Elapsed time: 1889.14s]
# [Epoch 171/200] [D loss: 0.271952] [G loss: 1.815502] [Elapsed time: 1900.35s]
# [Epoch 172/200] [D loss: 0.322322] [G loss: 1.691072] [Elapsed time: 1911.79s]
# [Epoch 173/200] [D loss: 0.316387] [G loss: 1.996820] [Elapsed time: 1922.86s]
# [Epoch 174/200] [D loss: 0.263707] [G loss: 1.873149] [Elapsed time: 1933.26s]
# [Epoch 175/200] [D loss: 0.341768] [G loss: 2.115745] [Elapsed time: 1943.85s]
# [Epoch 176/200] [D loss: 0.252889] [G loss: 2.036160] [Elapsed time: 1954.19s]
# [Epoch 177/200] [D loss: 0.278914] [G loss: 2.014390] [Elapsed time: 1965.26s]
# [Epoch 178/200] [D loss: 0.327468] [G loss: 1.597865] [Elapsed time: 1976.74s]
# [Epoch 179/200] [D loss: 0.332063] [G loss: 1.674161] [Elapsed time: 1987.76s]
# [Epoch 180/200] [D loss: 0.330903] [G loss: 1.903438] [Elapsed time: 1998.96s]
# [Epoch 181/200] [D loss: 0.241612] [G loss: 2.145297] [Elapsed time: 2010.36s]
# [Epoch 182/200] [D loss: 0.270212] [G loss: 1.972676] [Elapsed time: 2021.33s]
# [Epoch 183/200] [D loss: 0.266761] [G loss: 2.457010] [Elapsed time: 2031.82s]
# [Epoch 184/200] [D loss: 0.248633] [G loss: 2.387593] [Elapsed time: 2042.12s]
# [Epoch 185/200] [D loss: 0.259223] [G loss: 1.785050] [Elapsed time: 2052.40s]
# [Epoch 186/200] [D loss: 0.197081] [G loss: 2.193450] [Elapsed time: 2063.27s]
# [Epoch 187/200] [D loss: 0.304687] [G loss: 1.569021] [Elapsed time: 2074.72s]
# [Epoch 188/200] [D loss: 0.241568] [G loss: 2.403282] [Elapsed time: 2085.93s]
# [Epoch 189/200] [D loss: 0.309735] [G loss: 1.882901] [Elapsed time: 2096.43s]
# [Epoch 190/200] [D loss: 0.291508] [G loss: 1.864454] [Elapsed time: 2106.90s]
# [Epoch 191/200] [D loss: 0.295239] [G loss: 1.651136] [Elapsed time: 2117.30s]
# [Epoch 192/200] [D loss: 0.238941] [G loss: 2.362425] [Elapsed time: 2128.29s]
# [Epoch 193/200] [D loss: 0.229434] [G loss: 2.241656] [Elapsed time: 2139.87s]
# [Epoch 194/200] [D loss: 0.197702] [G loss: 2.097743] [Elapsed time: 2151.11s]
# [Epoch 195/200] [D loss: 0.321877] [G loss: 2.714439] [Elapsed time: 2161.46s]
# [Epoch 196/200] [D loss: 0.286055] [G loss: 2.229794] [Elapsed time: 2171.84s]
# [Epoch 197/200] [D loss: 0.273180] [G loss: 2.062502] [Elapsed time: 2182.30s]
# [Epoch 198/200] [D loss: 0.232148] [G loss: 2.697300] [Elapsed time: 2193.05s]
# [Epoch 199/200] [D loss: 0.291300] [G loss: 1.695196] [Elapsed time: 2204.56s]

# %%
from IPython.display import Image

Image('92000.png')
